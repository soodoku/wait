# %%
import pandas as pd

# %% [markdown]
# ## Load and Preprocess CA Census Data

# %%
# LOAD CA CENSUS DATA: Race, Age, Sex, Commuting, Median Income
ca_race_age_sex_df = pd.read_csv("../data/ca_census_data/ca_age_race_sex_ACSDP5Y2019.DP05_data_with_overlays_2020-12-15T230513.csv")
ca_communiting_characteristics_by_sex_df = pd.read_csv("../data/ca_census_data/ca_commuting_characteristics_by_sex_data_with_overlays_2020-12-24T124644.csv")
ca_median_income_past_12_months_df = pd.read_csv("../data/ca_census_data/ca_median_income_past_12_months_ACSST5Y2019.S1901_data_with_overlays_2020-12-15T192911.csv")

# %%
# Convert NAME to pure zip code number
ca_race_age_sex_df["ZIP"] = [zip.split()[1] for zip in ca_race_age_sex_df["NAME"]]
ca_communiting_characteristics_by_sex_df["ZIP"] = [zip.split()[1] for zip in ca_communiting_characteristics_by_sex_df["NAME"]]
ca_median_income_past_12_months_df["ZIP"] = [zip.split()[1] for zip in ca_median_income_past_12_months_df["NAME"]]

# %%
# just keep age, race, sex columns that we want
# ca_race_age_sex

# ZIP

# SEX AND AGE
# DP05_0004E - Sex ratio (males per 100 females)
# DP05_0005PE - percentage estimate of population under 5 yrs old
# DP05_0006PE - percentage estimate of population between 5-9
# DP05_0007PE - percentage estimate of population between 10-14
# DP05_0008PE - percentage estimate of population between 15-19
# DP05_0009PE - percentage estimate of population between 20-24 
# DP05_0010PE - percentage estimate of population between 25-34 
# DP05_0011PE - percentage estimate of population between 35-44 
# DP05_0012PE - percentage estimate of population between 45-54 
# DP05_0013PE - percentage estimate of population between 55-59 
# DP05_0014PE - percentage estimate of population between 60-64 
# DP05_0015PE - percentage estimate of population between 65-74 
# DP05_0016PE - percentage estimate of population between 75-84 
# DP05_0017PE - percentage estimate of population 85+

# RACE
# DP_05_0037PE - percentage of population that is White
# DP_05_0038PE - percentage of population that is Black or African American
# DP_05_0039PE - percentage of population that is American Indian and Alaska Native
# DP_05_0044PE - percentage of population that is Asian
# DP_05_0052PE - percentage of population that is Native Hawaiian and Other Pacific Islander
# DP_05_0071PE - percentage of population that is Hispanic or Latino


ca_race_age_sex_columns = ["ZIP",
                           "DP05_0004E","DP05_0005PE","DP05_0006PE", "DP05_0007PE", "DP05_0008PE",
                           "DP05_0009PE", "DP05_0010PE", "DP05_0011PE", "DP05_0012PE", "DP05_0013PE",
                           "DP05_0014PE", "DP05_0015PE", "DP05_0016PE", "DP05_0017PE",
                           "DP05_0037PE", "DP05_0038PE", "DP05_0039PE", "DP05_0044PE",
                           "DP05_0052PE", "DP05_0071PE"
                          ]



ca_ras_df = ca_race_age_sex_df[ca_race_age_sex_columns]

# %%
ca_ras_df.head()
# Out:
#      ZIP                                         DP05_0004E  \
# 0   Area  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1  90001                                              106.9
# 2  90002                                               91.2
# 3  90003                                               96.1
# 4  90004                                               97.2
#
#                                          DP05_0005PE  \
# 0  Percent!!SEX AND AGE!!Total population!!Under ...
# 1                                                8.4
# 2                                                9.0
# 3                                                9.1
# 4                                                5.8
#
#                                          DP05_0006PE  \
# 0  Percent!!SEX AND AGE!!Total population!!5 to 9...
# 1                                                9.0
# 2                                                8.9
# 3                                                8.3
# 4                                                5.7
#
#                                          DP05_0007PE  \
# 0  Percent!!SEX AND AGE!!Total population!!10 to ...
# 1                                                9.2
# 2                                                8.8
# 3                                                9.0
# 4                                                4.8
#
#                                          DP05_0008PE  \
# 0  Percent!!SEX AND AGE!!Total population!!15 to ...
# 1                                                8.4
# 2                                                8.9
# 3                                                8.9
# 4                                                5.0
#
#                                          DP05_0009PE  \
# 0  Percent!!SEX AND AGE!!Total population!!20 to ...
# 1                                                8.1
# 2                                                9.2
# 3                                                7.6
# 4                                                6.6
#
#                                          DP05_0010PE  \
# 0  Percent!!SEX AND AGE!!Total population!!25 to ...
# 1                                               16.2
# 2                                               14.5
# 3                                               17.0
# 4                                               21.7
#
#                                          DP05_0011PE  \
# 0  Percent!!SEX AND AGE!!Total population!!35 to ...
# 1                                               13.5
# 2                                               14.1
# 3                                               13.2
# 4                                               15.3
#
#                                          DP05_0012PE  ...  \
# 0  Percent!!SEX AND AGE!!Total population!!45 to ...  ...
# 1                                               11.4  ...
# 2                                               12.0  ...
# 3                                               12.0  ...
# 4                                               13.6  ...
#
#                                          DP05_0014PE  \
# 0  Percent!!SEX AND AGE!!Total population!!60 to ...
# 1                                                4.0
# 2                                                4.1
# 3                                                3.9
# 4                                                5.0
#
#                                          DP05_0015PE  \
# 0  Percent!!SEX AND AGE!!Total population!!65 to ...
# 1                                                4.5
# 2                                                3.8
# 3                                                3.8
# 4                                                6.9
#
#                                          DP05_0016PE  \
# 0  Percent!!SEX AND AGE!!Total population!!75 to ...
# 1                                                1.8
# 2                                                1.6
# 3                                                1.6
# 4                                                2.9
#
#                                          DP05_0017PE  \
# 0  Percent!!SEX AND AGE!!Total population!!85 yea...
# 1                                                0.6
# 2                                                0.8
# 3                                                0.8
# 4                                                1.0
#
#                                         DP05_0037PE  \
# 0  Percent!!RACE!!Total population!!One race!!White
# 1                                              41.9
# 2                                              43.0
# 3                                              33.1
# 4                                              35.7
#
#                                          DP05_0038PE  \
# 0  Percent!!RACE!!Total population!!One race!!Bla...
# 1                                                8.9
# 2                                               18.9
# 3                                               20.7
# 4                                                3.6
#
#                                          DP05_0039PE  \
# 0  Percent!!RACE!!Total population!!One race!!Ame...
# 1                                                0.8
# 2                                                1.5
# 3                                                0.7
# 4                                                0.2
#
#                                         DP05_0044PE  \
# 0  Percent!!RACE!!Total population!!One race!!Asian
# 1                                               0.3
# 2                                               1.0
# 3                                               0.3
# 4                                              25.5
#
#                                          DP05_0052PE  \
# 0  Percent!!RACE!!Total population!!One race!!Nat...
# 1                                                0.0
# 2                                                0.1
# 3                                                0.1
# 4                                                0.3
#
#                                          DP05_0071PE
# 0  Percent!!HISPANIC OR LATINO AND RACE!!Total po...
# 1                                               90.1
# 2                                               78.9
# 3                                               78.3
# 4                                               50.3
#
# [5 rows x 21 columns]

# %%
# just keep census columns that we want
# ca_communiting_characteristics_by_sex_df

# ZIP

# S0801_C01_002E - percent of workers age 16+ that drove a car, truck, or van to work
# S0801_C01_037E - percent of commuters with commute time less than 10 minutes
# S0801_C01_038E - percent of commuters with commute time 10-14 minutes
# S0801_C01_039E - percent of commuters with commute time 15-19 minutes
# S0801_C01_040E - percent of commuters with commute time 20-24 minutes
# S0801_C01_041E - percent of commuters with commute time 25-29 minutes
# S0801_C01_042E - percent of commuters with commute time 30-24 minutes
# S0801_C01_043E - percent of commuters with commute time 35-44 minutes
# S0801_C01_044E - percent of commuters with commute time 45-59 minutes
# S0801_C01_045E - percent of commuters with commute time 60+ minutes
# S0801_C01_046E - mean travel time to work in minutes

ca_communiting_characteristics_by_sex_columns = ["ZIP",
                                                 "S0801_C01_002E", "S0801_C01_037E", "S0801_C01_038E", "S0801_C01_039E", "S0801_C01_040E",
                                                 "S0801_C01_041E", "S0801_C01_042E", "S0801_C01_043E", "S0801_C01_044E", "S0801_C01_045E", "S0801_C01_046E",
                                                ]




ca_commute_df = ca_communiting_characteristics_by_sex_df[ca_communiting_characteristics_by_sex_columns]

# %%
ca_commute_df.head()
# Out:
#      ZIP                                     S0801_C01_002E  \
# 0   Area  Estimate!!Total!!Workers 16 years and over!!ME...
# 1  90001                                               79.9
# 2  90002                                               81.2
# 3  90003                                               81.6
# 4  90004                                               72.1
#
#                                       S0801_C01_037E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                                4.2
# 2                                                3.8
# 3                                                3.1
# 4                                                3.4
#
#                                       S0801_C01_038E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                                6.1
# 2                                                4.5
# 3                                                5.4
# 4                                                6.0
#
#                                       S0801_C01_039E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               12.6
# 2                                                8.9
# 3                                               10.1
# 4                                                9.4
#
#                                       S0801_C01_040E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               12.8
# 2                                               12.8
# 3                                               11.5
# 4                                               12.6
#
#                                       S0801_C01_041E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                                6.5
# 2                                                5.1
# 3                                                5.8
# 4                                                3.5
#
#                                       S0801_C01_042E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               21.7
# 2                                               22.9
# 3                                               21.5
# 4                                               33.8
#
#                                       S0801_C01_043E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               10.3
# 2                                               11.3
# 3                                                9.4
# 4                                                8.6
#
#                                       S0801_C01_044E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                                9.8
# 2                                               12.4
# 3                                               13.2
# 4                                               11.8
#
#                                       S0801_C01_045E  \
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               16.2
# 2                                               18.2
# 3                                               20.1
# 4                                               11.1
#
#                                       S0801_C01_046E
# 0  Estimate!!Total!!Workers 16 years and over who...
# 1                                               33.8
# 2                                               36.5
# 3                                               36.9
# 4                                               32.2

# %%
# just keep census columns that we want
# ca_median_income_past_12_months_df

# S1901_C01_012E - median household income
# S1901_C01_013 - mean household income

ca_median_income_past_12_months_columns = ["ZIP", "S1901_C01_012E", "S1901_C01_013E"]

ca_income_df = ca_median_income_past_12_months_df[ca_median_income_past_12_months_columns]

# %%
ca_income_df.head()
# Out:
#      ZIP                                 S1901_C01_012E  \
# 0   Area  Estimate!!Households!!Median income (dollars)
# 1  90001                                          43360
# 2  90002                                          37285
# 3  90003                                          40598
# 4  90004                                          49675
#
#                                 S1901_C01_013E
# 0  Estimate!!Households!!Mean income (dollars)
# 1                                        54325
# 2                                        49724
# 3                                        51181
# 4                                        84325

# %%
# rename columns with more descriptive names
# drop first row of each df (header text)

# SEX AND AGE
# DP05_0004E - Sex ratio (males per 100 females)
# DP05_0005PE - percentage estimate of population under 5 yrs old
# DP05_0006PE - percentage estimate of population between 5-9
# DP05_0007PE - percentage estimate of population between 10-14
# DP05_0008PE - percentage estimate of population between 15-19
# DP05_0009PE - percentage estimate of population between 20-24 
# DP05_0010PE - percentage estimate of population between 25-34 
# DP05_0011PE - percentage estimate of population between 35-44 
# DP05_0012PE - percentage estimate of population between 45-54 
# DP05_0013PE - percentage estimate of population between 55-59 
# DP05_0014PE - percentage estimate of population between 60-64 
# DP05_0015PE - percentage estimate of population between 65-74 
# DP05_0016PE - percentage estimate of population between 75-84 
# DP05_0017PE - percentage estimate of population 85+

# RACE
# DP_05_0037PE - percentage of population that is White
# DP_05_0038PE - percentage of population that is Black or African American
# DP_05_0039PE - percentage of population that is American Indian and Alaska Native
# DP_05_0044PE - percentage of population that is Asian
# DP_05_0052PE - percentage of population that is Native Hawaiian and Other Pacific Islander
# DP_05_0071PE - percentage of population that is Hispanic or Latino


ca_ras_rename_columns_dict = {
    "DP05_0004E" : "males_per_100_females",
    "DP05_0005PE" : "p_pop_under_5",
    "DP05_0006PE" : "p_pop_between_5_9",
    "DP05_0007PE" : "p_pop_between_10_14",
    "DP05_0008PE" : "p_pop_between_15_19",
    "DP05_0009PE" : "p_pop_between_20_24",
    "DP05_0010PE" : "p_pop_between_25_34",
    "DP05_0011PE" : "p_pop_between_35_44",
    "DP05_0012PE" : "p_pop_between_45_54",
    "DP05_0013PE" : "p_pop_between_55_59",
    "DP05_0014PE" : "p_pop_between_60_64", 
    "DP05_0015PE" : "p_pop_between_65_74", 
    "DP05_0016PE" : "p_pop_between_75_84", 
    "DP05_0017PE" : "p_pop_over_84",
    "DP05_0037PE" : "p_pop_white", 
    "DP05_0038PE" : "p_pop_black" , 
    "DP05_0039PE" : "p_pop_am_indian_alaskan_native", 
    "DP05_0044PE" : "p_pop_asian",
    "DP05_0052PE" : "p_pop_native_hawaiian_pacific_islander", 
    "DP05_0071PE" : "p_pop_hispanic_latino"
}


ca_ras_df.rename(columns=ca_ras_rename_columns_dict, inplace=True)
ca_ras_df = ca_ras_df.iloc[1:]
ca_ras_df.head()
# Out:
# /Users/noahfinberg/Desktop/GauravCollab/env/lib/python3.9/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ZIP males_per_100_females p_pop_under_5 p_pop_between_5_9  \
# 1  90001                 106.9           8.4               9.0
# 2  90002                  91.2           9.0               8.9
# 3  90003                  96.1           9.1               8.3
# 4  90004                  97.2           5.8               5.7
# 5  90005                 101.8           5.5               5.5
#
#   p_pop_between_10_14 p_pop_between_15_19 p_pop_between_20_24  \
# 1                 9.2                 8.4                 8.1
# 2                 8.8                 8.9                 9.2
# 3                 9.0                 8.9                 7.6
# 4                 4.8                 5.0                 6.6
# 5                 4.7                 4.5                 6.7
#
#   p_pop_between_25_34 p_pop_between_35_44 p_pop_between_45_54  ...  \
# 1                16.2                13.5                11.4  ...
# 2                14.5                14.1                12.0  ...
# 3                17.0                13.2                12.0  ...
# 4                21.7                15.3                13.6  ...
# 5                21.8                17.0                12.2  ...
#
#   p_pop_between_60_64 p_pop_between_65_74 p_pop_between_75_84 p_pop_over_84  \
# 1                 4.0                 4.5                 1.8           0.6
# 2                 4.1                 3.8                 1.6           0.8
# 3                 3.9                 3.8                 1.6           0.8
# 4                 5.0                 6.9                 2.9           1.0
# 5                 4.2                 6.8                 4.4           1.5
#
#   p_pop_white p_pop_black p_pop_am_indian_alaskan_native p_pop_asian  \
# 1        41.9         8.9                            0.8         0.3
# 2        43.0        18.9                            1.5         1.0
# 3        33.1        20.7                            0.7         0.3
# 4        35.7         3.6                            0.2        25.5
# 5        23.3         5.8                            0.5        34.2
#
#   p_pop_native_hawaiian_pacific_islander p_pop_hispanic_latino
# 1                                    0.0                  90.1
# 2                                    0.1                  78.9
# 3                                    0.1                  78.3
# 4                                    0.3                  50.3
# 5                                    0.2                  49.5
#
# [5 rows x 21 columns]

# %%
# S0801_C01_002E - percent of workers age 16+ that drove a car, truck, or van to work
# S0801_C01_037E - percent of commuters with commute time less than 10 minutes
# S0801_C01_038E - percent of commuters with commute time 10-14 minutes
# S0801_C01_039E - percent of commuters with commute time 15-19 minutes
# S0801_C01_040E - percent of commuters with commute time 20-24 minutes
# S0801_C01_041E - percent of commuters with commute time 25-29 minutes
# S0801_C01_042E - percent of commuters with commute time 30-34 minutes
# S0801_C01_043E - percent of commuters with commute time 35-44 minutes
# S0801_C01_044E - percent of commuters with commute time 45-59 minutes
# S0801_C01_045E - percent of commuters with commute time 60+ minutes
# S0801_C01_046E - mean travel time to work in minutes

ca_commutting_rename_columns_dict = {
    "S0801_C01_002E" : "p_drive_to_work",
    "S0801_C01_037E" : "p_commute_under_10",
    "S0801_C01_038E" : "p_commute_between_10_14",
    "S0801_C01_039E" : "p_commute_between_15_19",
    "S0801_C01_040E" : "p_commute_between_20_24",
    "S0801_C01_041E" : "p_commute_between_25_29", 
    "S0801_C01_042E" : "p_commute_between_30_34", 
    "S0801_C01_043E" : "p_commute_between_35_44", 
    "S0801_C01_044E" : "p_commute_between_45_59", 
    "S0801_C01_045E" : "p_commute_over_59", 
    "S0801_C01_046E" : "mean_commute_time_minutes"
}

ca_commute_df.rename(columns=ca_commutting_rename_columns_dict, inplace=True)
ca_commute_df = ca_commute_df.iloc[1:]
ca_commute_df.head()
# Out:
# /Users/noahfinberg/Desktop/GauravCollab/env/lib/python3.9/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ZIP p_drive_to_work p_commute_under_10 p_commute_between_10_14  \
# 1  90001            79.9                4.2                     6.1
# 2  90002            81.2                3.8                     4.5
# 3  90003            81.6                3.1                     5.4
# 4  90004            72.1                3.4                     6.0
# 5  90005            59.7                4.2                     7.4
#
#   p_commute_between_15_19 p_commute_between_20_24 p_commute_between_25_29  \
# 1                    12.6                    12.8                     6.5
# 2                     8.9                    12.8                     5.1
# 3                    10.1                    11.5                     5.8
# 4                     9.4                    12.6                     3.5
# 5                     9.8                    11.7                     3.0
#
#   p_commute_between_30_34 p_commute_between_35_44 p_commute_between_45_59  \
# 1                    21.7                    10.3                     9.8
# 2                    22.9                    11.3                    12.4
# 3                    21.5                     9.4                    13.2
# 4                    33.8                     8.6                    11.8
# 5                    29.7                     6.5                    12.0
#
#   p_commute_over_59 mean_commute_time_minutes
# 1              16.2                      33.8
# 2              18.2                      36.5
# 3              20.1                      36.9
# 4              11.1                      32.2
# 5              15.6                      33.9

# %%
# S1901_C01_012E - median household income
# S1901_C01_013 - mean household income

ca_income_rename_columns_dict = {
    "S1901_C01_012E": "median_household_income", 
    "S1901_C01_013E": "mean_household_income" 
}

ca_income_df.rename(columns=ca_income_rename_columns_dict, inplace=True)
ca_income_df = ca_income_df.iloc[1:]
ca_income_df.head()
# Out:
# /Users/noahfinberg/Desktop/GauravCollab/env/lib/python3.9/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ZIP median_household_income mean_household_income
# 1  90001                   43360                 54325
# 2  90002                   37285                 49724
# 3  90003                   40598                 51181
# 4  90004                   49675                 84325
# 5  90005                   38491                 54841

# %%
# join all census dfs on ZIP
census_df = pd.merge(ca_ras_df,ca_commute_df,on='ZIP',how='outer')
census_df = pd.merge(census_df, ca_income_df, on="ZIP", how="outer")
census_df.head()
# Out:
#      ZIP males_per_100_females p_pop_under_5 p_pop_between_5_9  \
# 0  90001                 106.9           8.4               9.0
# 1  90002                  91.2           9.0               8.9
# 2  90003                  96.1           9.1               8.3
# 3  90004                  97.2           5.8               5.7
# 4  90005                 101.8           5.5               5.5
#
#   p_pop_between_10_14 p_pop_between_15_19 p_pop_between_20_24  \
# 0                 9.2                 8.4                 8.1
# 1                 8.8                 8.9                 9.2
# 2                 9.0                 8.9                 7.6
# 3                 4.8                 5.0                 6.6
# 4                 4.7                 4.5                 6.7
#
#   p_pop_between_25_34 p_pop_between_35_44 p_pop_between_45_54  ...  \
# 0                16.2                13.5                11.4  ...
# 1                14.5                14.1                12.0  ...
# 2                17.0                13.2                12.0  ...
# 3                21.7                15.3                13.6  ...
# 4                21.8                17.0                12.2  ...
#
#   p_commute_between_15_19 p_commute_between_20_24 p_commute_between_25_29  \
# 0                    12.6                    12.8                     6.5
# 1                     8.9                    12.8                     5.1
# 2                    10.1                    11.5                     5.8
# 3                     9.4                    12.6                     3.5
# 4                     9.8                    11.7                     3.0
#
#   p_commute_between_30_34 p_commute_between_35_44 p_commute_between_45_59  \
# 0                    21.7                    10.3                     9.8
# 1                    22.9                    11.3                    12.4
# 2                    21.5                     9.4                    13.2
# 3                    33.8                     8.6                    11.8
# 4                    29.7                     6.5                    12.0
#
#   p_commute_over_59 mean_commute_time_minutes median_household_income  \
# 0              16.2                      33.8                   43360
# 1              18.2                      36.5                   37285
# 2              20.1                      36.9                   40598
# 3              11.1                      32.2                   49675
# 4              15.6                      33.9                   38491
#
#   mean_household_income
# 0                 54325
# 1                 49724
# 2                 51181
# 3                 84325
# 4                 54841
#
# [5 rows x 34 columns]

# %%
# Load DMV data
dmv_df = pd.read_csv("../data/dmv_data_output_12_14_2020.csv", index_col=0)
dmv_descriptive_stats = pd.read_csv("../data/dmv_wait_descriptive_stats.csv", index_col=0)

dmv_df = pd.merge(dmv_df, dmv_descriptive_stats, on="name", how="outer")
dmv_df.rename(columns={" zip": "ZIP"}, inplace=True) # rename to match other df

dmv_df.head()
# Out:
#                                     street      locality  region    ZIP  SU0  \
# name
# Alturas                         903 W C St       Alturas      CA  96101  NaN
# Arleta                 14400 Van Nuys Blvd        Arleta      CA  91331  NaN
# Arvin                        317 Campus Dr         Arvin      CA  93203  NaN
# Auburn                 11722 Enterprise Dr        Auburn      CA  95603  NaN
# Bakersfield Southwest      7000 Schirra Ct   Bakersfield      CA  93313  NaN
#
#                        SU1  SU2  SU3  SU4  SU5  ...  9_weekday_hour_avg_wait  \
# name                                            ...
# Alturas                NaN  NaN  NaN  NaN  NaN  ...                      1.0
# Arleta                 NaN  NaN  NaN  NaN  NaN  ...                     21.0
# Arvin                  NaN  NaN  NaN  NaN  NaN  ...                     23.0
# Auburn                 NaN  NaN  NaN  NaN  NaN  ...                     17.8
# Bakersfield Southwest  NaN  NaN  NaN  NaN  NaN  ...                     28.8
#
#                        10_weekday_hour_avg_wait  11_weekday_hour_avg_wait  \
# name
# Alturas                                     1.4                       1.2
# Arleta                                     33.4                      28.8
# Arvin                                      22.6                      24.6
# Auburn                                     21.8                      23.8
# Bakersfield Southwest                      34.4                      30.6
#
#                        12_weekday_hour_avg_wait  13_weekday_hour_avg_wait  \
# name
# Alturas                                     0.0                       2.0
# Arleta                                     29.2                      30.0
# Arvin                                      25.6                      26.8
# Auburn                                     28.4                      26.0
# Bakersfield Southwest                      28.8                      25.6
#
#                        14_weekday_hour_avg_wait  15_weekday_hour_avg_wait  \
# name
# Alturas                                     1.2                       1.0
# Arleta                                     28.0                      35.2
# Arvin                                      21.2                      20.8
# Auburn                                     18.0                      22.0
# Bakersfield Southwest                      25.8                      28.8
#
#                        16_weekday_hour_avg_wait  17_weekday_hour_avg_wait  \
# name
# Alturas                                     0.6                       0.0
# Arleta                                     17.6                       3.4
# Arvin                                       9.0                       0.4
# Auburn                                     12.4                       0.0
# Bakersfield Southwest                      12.4                       0.0
#
#                        18_weekday_hour_avg_wait
# name
# Alturas                                     0.0
# Arleta                                      0.0
# Arvin                                       0.0
# Auburn                                      0.0
# Bakersfield Southwest                       0.0
#
# [5 rows x 279 columns]

# %%
# Left Join DMV data and Census data
census_df["ZIP"] = census_df["ZIP"].astype(str).astype(int) #make sure columns match
combined_df = pd.merge(dmv_df, census_df, on="ZIP", how="left")

# %%
dmv_df["weekday_wait_50"]
# Out:
# name
# Alturas                   1.0
# Arleta                   20.0
# Arvin                    13.5
# Auburn                   15.5
# Bakersfield Southwest    17.5
#                          ...
# Oroville                  4.5
# Ridgecrest                8.5
# San Andreas               5.0
# South Lake Tahoe          8.0
# Truckee                  17.0
# Name: weekday_wait_50, Length: 175, dtype: float64

# %% [markdown]
# ## Plot Basic Loess

# %%
# Plot Loess
import numpy as np
import seaborn as sns

# median household income and average weekday wait
loess_median_income_df = combined_df[["weekday_wait_50", "median_household_income"]]
loess_median_income_df = loess_median_income_df[loess_median_income_df['median_household_income'].notna()] # make sure median household income is non NaN
loess_median_income_df["median_household_income"] = loess_median_income_df["median_household_income"].astype(int)

ax = sns.regplot(x="median_household_income", y="weekday_wait_50", data=loess_median_income_df,
           lowess=True);

ax.set_xlabel("Median Household Income ($)")
ax.set_ylabel("Average Wait Time (minutes)")
ax.set_title("Relationship Between Median Household Income and Average Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_median_household_income_dmv_average_wait.png')

# %%
# median household income and average short weekday wait
loess_median_income_df = combined_df[["weekday_wait_25", "median_household_income"]]
loess_median_income_df = loess_median_income_df[loess_median_income_df['median_household_income'].notna()] # make sure median household income is non NaN
loess_median_income_df["median_household_income"] = loess_median_income_df["median_household_income"].astype(int)
ax = sns.regplot(x="median_household_income", y="weekday_wait_25", data=loess_median_income_df,
           lowess=True);

ax.set_xlabel("Median Household Income ($)")
ax.set_ylabel("25th Percentile Wait Time (minutes)")
ax.set_title("Relationship Between Median Household Income and 25th Percentile Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_median_household_income_dmv_25_percentile_wait.png')

# %%
# median household income and average long weekday wait
loess_median_income_df = combined_df[["weekday_wait_75", "median_household_income"]]
loess_median_income_df = loess_median_income_df[loess_median_income_df['median_household_income'].notna()] # make sure median household income is non NaN
loess_median_income_df["median_household_income"] = loess_median_income_df["median_household_income"].astype(int)
ax = sns.regplot(x="median_household_income", y="weekday_wait_75", data=loess_median_income_df,
           lowess=True);

ax.set_xlabel("Median Household Income ($)")
ax.set_ylabel("75th Percentile Wait Time (minutes)")
ax.set_title("Relationship Between Median Household Income and 75th Percentile Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_median_household_income_dmv_75_percentile_wait.png')

# %%
# % White and average weekday wait
loess_p_white_df = combined_df[["weekday_wait_50", "p_pop_white"]]

loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)
loess_p_white_df = loess_p_white_df[loess_p_white_df['p_pop_white'].notna()] # make sure median household income is non NaN
ax = sns.regplot(x="p_pop_white", y="weekday_wait_50", data=loess_p_white_df,
           lowess=True);

ax.set_xlabel("percentage of population that is white")
ax.set_ylabel("average wait time (minutes)")
ax.set_title("Relationship Between Race and Average Wait Time at the CA DMV")


figure = ax.get_figure()    
figure.savefig('../images/loess_percentage_of_population_white_dmv_average_wait.png')
# Out:
# <ipython-input-65-f0d0dc809f16>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)

# %%
# % White and average short weekday wait
loess_p_white_df = combined_df[["weekday_wait_25", "p_pop_white"]]

loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)
loess_p_white_df = loess_p_white_df[loess_p_white_df['p_pop_white'].notna()] # make sure median household income is non NaN
ax = sns.regplot(x="p_pop_white", y="weekday_wait_25", data=loess_p_white_df,
           lowess=True);

ax.set_xlabel("percentage of population that is white")
ax.set_ylabel("75th percentile wait time (minutes)")
ax.set_title("Relationship Between Race and 75th Percentile Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_percentage_of_population_white_dmv_75_percentile_wait.png')
# Out:
# <ipython-input-66-c453ab231e82>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)

# %%
# % White and average long weekday wait
loess_p_white_df = combined_df[["weekday_wait_75", "p_pop_white"]]

loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)
loess_p_white_df = loess_p_white_df[loess_p_white_df['p_pop_white'].notna()] # make sure median household income is non NaN
ax = sns.regplot(x="p_pop_white", y="weekday_wait_75", data=loess_p_white_df,
           lowess=True);

ax.set_xlabel("percentage of population that is white")
ax.set_ylabel("25th percentile wait time (minutes)")
ax.set_title("Relationship Between Race and 25th Percentile Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_percentage_of_population_white_dmv_25_percentile_wait.png')
# Out:
# <ipython-input-67-ecd0e2fc6003>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_p_white_df["p_pop_white"] = loess_p_white_df["p_pop_white"].astype(float)

# %%
# daily commute length and average weekday wait
loess_commute_df = combined_df[["weekday_wait_50", "mean_commute_time_minutes"]]

loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)
loess_commute_df = loess_commute_df[loess_commute_df['mean_commute_time_minutes'].notna()] # make sure median household income is non NaN
sns.regplot(x="mean_commute_time_minutes", y="weekday_wait_50", data=loess_commute_df,
           lowess=True);

ax.set_xlabel("average daily commute (minutes)")
ax.set_ylabel("average wait time (minutes)")
ax.set_title("Relationship Between Average Daily Commute and Average Wait Time at the CA DMV")

figure = ax.get_figure()    
figure.savefig('../images/loess_avg_commute_dmv_avg_wait.png')
# Out:
# <ipython-input-68-ca4bb5440fae>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)

# %%
# daily commute length and average short weekday wait
loess_commute_df = combined_df[["weekday_wait_25", "mean_commute_time_minutes"]]

loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)
loess_commute_df = loess_commute_df[loess_commute_df['mean_commute_time_minutes'].notna()] # make sure median household income is non NaN
sns.regplot(x="mean_commute_time_minutes", y="weekday_wait_25", data=loess_commute_df,
           lowess=True);
# Out:
# <ipython-input-44-ebb09517776b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)

# %%
# daily commute length and average long weekday wait
loess_commute_df = combined_df[["weekday_wait_75", "mean_commute_time_minutes"]]

loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)
loess_commute_df = loess_commute_df[loess_commute_df['mean_commute_time_minutes'].notna()] # make sure median household income is non NaN
sns.regplot(x="mean_commute_time_minutes", y="weekday_wait_75", data=loess_commute_df,
           lowess=True);
# Out:
# <ipython-input-45-a1bbf80dafd9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loess_commute_df["mean_commute_time_minutes"] = loess_commute_df["mean_commute_time_minutes"].astype(float)
